# %%
#!g1.4
# %%bash
cd poincare-embedding
make
# Out:
# [100%] Built target poincare_embedding

# %%
#!g1.4
# %%bash
cd poincare-embedding
pip install nltk
echo "done"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# done
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
#!g1.4
# %%bash
python3 -c "import nltk; nltk.download('wordnet')"
echo "done"
# Out:
# done
# [nltk_data] Downloading package wordnet to /home/jupyter/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#!g1.4
# %%bash
cd poincare-embedding
./poincare_embedding ./wordnet_dataset.tsv ./wordnet_embeddings_1.tsv -d 10 -t 30 -e 1500 -l 0.1 -L 0.0001 -n 50 -s 1337
# Out:
# settings:
#   data_file             : ./wordnet_dataset.tsv
#   result_embedding_file : ./wordnet_embeddings.tsv
#   seed                  : 1337
#   num_threads           : 30
#   neg_size              : 50
#   max_epoch             : 1500
#   dim                   : 10
#   lr0                   : 0.1
#   lr1                   : 0.0001
#   uniform_range         : 0.001
#
# read data
# data size: 682192
# start training
# embedding size: 67176 x 10
# num_threads = 30
# data size = 22739/thread
# epoch 1/1500 start
#   100 %    671427.17 itr/sec    loss: 3.94
# epoch 2/1500 start
#   100 %    503818.32 itr/sec    loss: 3.60
# epoch 3/1500 start
#   100 %    570853.56 itr/sec    loss: 3.26
# epoch 4/1500 start
#   100 %    552364.37 itr/sec    loss: 2.92
# epoch 5/1500 start
#   100 %    543995.22 itr/sec    loss: 2.69
# epoch 6/1500 start
#   100 %    559155.74 itr/sec    loss: 2.53
# epoch 7/1500 start
#   100 %    551025.85 itr/sec    loss: 2.43
# epoch 8/1500 start
# ...

# %%
#!g1.4
# %%bash
cd poincare-embedding
./poincare_embedding ./wordnet_dataset.tsv ./wordnet_embeddings_2.tsv -d 2 -t 30 -e 1000 -l 0.1 -L 0.0001 -n 20 -s 0
# Out:
# settings:
#   data_file             : ./wordnet_dataset.tsv
#   result_embedding_file : ./wordnet_embeddings_2.tsv
#   seed                  : 0
#   num_threads           : 30
#   neg_size              : 20
#   max_epoch             : 1000
#   dim                   : 2
#   lr0                   : 0.1
#   lr1                   : 0.0001
#   uniform_range         : 0.001
#
# read data
# data size: 682192
# start training
# embedding size: 67176 x 2
# num_threads = 30
# data size = 22739/thread
# epoch 1/1000 start
#   100 %    2368645.83 itr/sec    loss: 3.21
# epoch 2/1000 start
#   100 %    1628090.69 itr/sec    loss: 2.88
# epoch 3/1000 start
#   100 %    1705425.00 itr/sec    loss: 2.68
# epoch 4/1000 start
#   100 %    1718312.34 itr/sec    loss: 2.50
# epoch 5/1000 start
#   100 %    1684370.37 itr/sec    loss: 2.34
# epoch 6/1000 start
#   100 %    1651743.34 itr/sec    loss: 2.23
# epoch 7/1000 start
#   100 %    1753650.39 itr/sec    loss: 2.15
# epoch 8/1000 start
# ...

# %%
#!g1.4
# %%bash
cd poincare-embedding
./poincare_embedding ./wordnet_dataset.tsv ./wordnet_embeddings_3.tsv -d 100 -t 30 -e 1500 -l 0.1 -L 0.0001 -n 50 -s 0
# Out:
# settings:
#   data_file             : ./wordnet_dataset.tsv
#   result_embedding_file : ./wordnet_embeddings_3.tsv
#   seed                  : 0
#   num_threads           : 30
#   neg_size              : 50
#   max_epoch             : 1500
#   dim                   : 100
#   lr0                   : 0.1
#   lr1                   : 0.0001
#   uniform_range         : 0.001
#
# read data
# data size: 682192
# start training
# embedding size: 67176 x 100
# num_threads = 30
# data size = 22739/thread
# epoch 1/1500 start
#   100 %    196477.53 itr/sec    loss: 3.89
# epoch 2/1500 start
#   100 %    187409.34 itr/sec    loss: 3.61
# epoch 3/1500 start
#   100 %    189439.04 itr/sec    loss: 3.21
# epoch 4/1500 start
#   100 %    188809.85 itr/sec    loss: 2.89
# epoch 5/1500 start
#   100 %    191244.74 itr/sec    loss: 2.67
# epoch 6/1500 start
#   100 %    194350.43 itr/sec    loss: 2.50
# epoch 7/1500 start
#   100 %    190656.79 itr/sec    loss: 2.41
# epoch 8/1500 start
# ...

# %%
#!g1.4

# %%
#!g1.4
# %%bash
cd poincare-embedding
./poincare_embedding ./wordnet_dataset.tsv ./wordnet_embeddings_4.tsv -d 100 -t 30 -e 1000 -l 0.1 -L 0.0001 -n 1000 -s 0
# Out:
# settings:
#   data_file             : ./wordnet_dataset.tsv
#   result_embedding_file : ./wordnet_embeddings_4.tsv
#   seed                  : 0
#   num_threads           : 30
#   neg_size              : 1000
#   max_epoch             : 1000
#   dim                   : 100
#   lr0                   : 0.1
#   lr1                   : 0.0001
#   uniform_range         : 0.001
#
# read data
# data size: 682192
# start training
# embedding size: 67176 x 100
# num_threads = 30
# data size = 22739/thread
# epoch 1/1000 start
#   100 %    7955.43 itr/sec    loss: 6.86
# epoch 2/1000 start
#   100 %    7897.41 itr/sec    loss: 6.57
# epoch 3/1000 start
#   100 %    7974.12 itr/sec    loss: 6.14
# epoch 4/1000 start
#   100 %    7844.37 itr/sec    loss: 5.76
# epoch 5/1000 start
#   100 %    7887.54 itr/sec    loss: 5.50
# epoch 6/1000 start
#   100 %    7786.62 itr/sec    loss: 5.29
# epoch 7/1000 start
#   100 %    7972.16 itr/sec    loss: 5.17
# epoch 8/1000 start
# ...

# %%
#!g1.4
# %%bash
cd poincare-embedding
./poincare_embedding ./wordnet_dataset.tsv ./wordnet_embeddings_5.tsv -d 200 -t 30 -e 1000 -l 0.1 -L 0.0001 -n 1000 -s 0
# Out:
# settings:
#   data_file             : ./wordnet_dataset.tsv
#   result_embedding_file : ./wordnet_embeddings_5.tsv
#   seed                  : 0
#   num_threads           : 30
#   neg_size              : 1000
#   max_epoch             : 1000
#   dim                   : 200
#   lr0                   : 0.1
#   lr1                   : 0.0001
#   uniform_range         : 0.001
#
# read data
# data size: 682192
# start training
# embedding size: 67176 x 200
# num_threads = 30
# data size = 22739/thread
# epoch 1/1000 start
#   100 %    4211.94 itr/sec    loss: 6.86
# epoch 2/1000 start
#   100 %    4093.13 itr/sec    loss: 6.57
# epoch 3/1000 start
#   100 %    4138.98 itr/sec    loss: 6.14
# epoch 4/1000 start
#   100 %    4092.18 itr/sec    loss: 5.76
# epoch 5/1000 start
#   100 %    4229.80 itr/sec    loss: 5.50
# epoch 6/1000 start
#   100 %    4089.58 itr/sec    loss: 5.29
# epoch 7/1000 start
#   100 %    4012.41 itr/sec    loss: 5.17
# epoch 8/1000 start
# ...

# %%
#!g1.4
# Out:
# settings:
#   data_file             : ./wordnet_dataset.tsv
#   result_embedding_file : ./wordnet_embeddings_6.tsv
#   seed                  : 0
#   num_threads           : 30
#   neg_size              : 20
#   max_epoch             : 1000
#   dim                   : 10
#   lr0                   : 0.1
#   lr1                   : 0.0001
#   uniform_range         : 0.001
#
# read data
# data size: 682192
# start training
# embedding size: 67176 x 10
# num_threads = 30
# data size = 22739/thread
# epoch 1/1000 start
#   100 %    1332363.28 itr/sec    loss: 3.04
# epoch 2/1000 start
#   100 %    1194693.52 itr/sec    loss: 2.75
# epoch 3/1000 start
#   100 %    1229135.14 itr/sec    loss: 2.44
# epoch 4/1000 start
#   100 %    1244835.77 itr/sec    loss: 2.16
# epoch 5/1000 start
#   100 %    1238058.08 itr/sec    loss: 1.97
# epoch 6/1000 start
#   100 %    1162129.47 itr/sec    loss: 1.82
# epoch 7/1000 start
#   100 %    1188449.48 itr/sec    loss: 1.74
# epoch 8/1000 start
# ...
